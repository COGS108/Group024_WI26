# %% [markdown]
# # COGS 108 - Project Proposal
#
# ## Authors

# %% [markdown]
# - Brett Kinsella: Background research, Conceptualization, Methodology, Project administration, Writing – original draft
# - Ammar Allaw: Data gathering, Data organization
# - Alan Aquino:
# - Adan Perez Olmos:
# - Dan Woo:

# %% [markdown]
# ## Research Question

# %% [markdown]
# What is the significance of the yen carry trade as it relates to global markets?
# - What metrics are indicative of a Yen carry trade unwind in Japanese financial markets?
# - Can we model a correlation between metrics indicative of a Yen carry trade unwind and volatility in US stocks?
# - More Specifically, can a composite carry trade stress index derived from Japanese Government Bonds (JGB) yield volatility and US-Japan interest rate differentials reliably quantify systemic risk and detect the Yen carry trade unwinding events of August 2024 and January 2026?

# %% [markdown]
# ## Background and Prior Work

# %% [markdown]
# Big players in the global financial market (hedge funds, investment banks, mutual funds, etc.) borrow Yen for highly leveraged transactions due to the extremely low borrowing costs (~0.75% currently) since the stagnation of their economy began around 1990, known as the Yen carry trade.<a name="cite_ref-1"></a>[<sup>1</sup>](#cite_note-1) If the Yen increases in value due to forces in the Japanese bond market or domestic policy change then these investors are forced to liquidate their positions which can send shock waves through global markets known as the unwind of the Yen carry trade.<a name="cite_ref-2"></a>[<sup>2</sup>](#cite_note-2) Japan recently elected a new Prime Minister, Sanae Takaichi, and she has called for significant tax cuts and an increase of government spending to combat persistent inflation despite Japan having the highest debt-to-GDP ratio in the world at 236.7 % in 2024.<a name="cite_ref-3"></a>[<sup>3</sup>](#cite_note-3) <a name="cite_ref-4"></a>[<sup>4</sup>](#cite_note-4) The Japanese government bond (JGB) market has reacted negatively to this plan with an increase in volatility that pushed the bond yields to all time highs, creating conditions for potential yen appreciation as Japanese institutions consider repatriating capital from foreign markets.<a name="cite_ref-5"></a>[<sup>5</sup>](#cite_note-5) <a name="cite_ref-6"></a>[<sup>6</sup>](#cite_note-6)  This created the scenario where the Yen carry trade has started to unwind and the ripples of such were felt across the global markets. The ongoing situation in Japan has the potential to create a global financial crisis in the worst case scenario with some likening its potential ramifications to the 2008 global financial crisis.<a name="cite_note-7"></a> [<sup>7</sup>](#cite_ref-7) <a name="cite_note-8"></a> [<sup>8</sup>](#cite_ref-8)
#
# In 2024 and 2026: Paragraph describing events that happened in 2024 and 2026 specifically
#
# Paragraph on any previous work that has been done on Yen carry trade modeling.  See  <a name="cite_note-8"></a> [<sup>8</sup>](#cite_ref-8) for one example that was done in 2009 and their attempt to find its impact on the 2008 crisis.
#
#
# 1. <a name="cite_note-1"></a> [^](#cite_ref-1) Yahoo Finance Singapore. (n.d.) Yen carry trade: Why did... *Yahoo Finance*. https://sg.finance.yahoo.com/news/yen-carry-trade-why-did-090756012.html
#
# 2. <a name="cite_note-2"></a> [^](#cite_ref-2) (12 Aug 2024) Global Markets Reacts To The Japanese Yen Carry Trade Unwind. *Forbes*. https://www.forbes.com/sites/greatspeculations/2024/08/12/global-markets-reacts-to-the-japanese-yen-carry-trade-unwind/
#
# 3. <a name="cite_note-3"></a> [^](#cite_ref-3) Trading Economics. (2024) Japan Government Debt to GDP. *Trading Economics*. https://tradingeconomics.com/japan/government-debt-to-gdp
#
# 4. <a name="cite_note-4"></a> [^](#cite_ref-4) (27 Jan 2026) Why Japan's economic plans are sending jitters through global markets. *Al Jazeera*. https://www.aljazeera.com/economy/2026/1/27/why-japans-economic-plans-are-sending-jitters-through-global-markets
#
# 5. <a name="cite_note-5"></a> [^](#cite_ref-5) Wright Research. (n.d.) Japan's Bond Market Crash: What Just Happened and Why It Matters for Global Markets. *Wright Research*. https://www.wrightresearch.in/blog/japans-bond-market-crash-what-just-happened-and-why-it-matters-for-global-markets/
#
# 6. <a name="cite_note-6"></a> [^](#cite_ref-6) CNBC. (23 Jan 2026) BOJ rate decision, snap election, Takaichi, GDP. *CNBC*. https://www.cnbc.com/2026/01/23/boj-rate-decision-snap-election-takaichi-gdp.html
#
# 7. <a name="cite_note-7"></a> [^](#cite_ref-7) Bloomberg. (25 Jan 2026) Japan Bond Market Crash Raises Alarm for Global Interest Rates. *Bloomberg*. https://archive.is/20260129064728/https://www.bloomberg.com/news/features/2026-01-25/japan-bond-market-crash-raises-alarm-for-global-interest-rates
#
# 8. <a name="cite_note-8"></a> [^](#cite_ref-8) Hattori, M., & Shin, H. S. (3 Jun 2009) Yen Carry Trade and the Subprime Crisis. *IMF eLibrary*. ISBN: 9781589067950. https://www.elibrary.imf.org/view/journals/024/2009/002/article-A007-en.xml

# %% [markdown]
# ## Hypothesis

# %% [markdown]
# We believe that a spike in Japanese Government Bonds (JGB) yield volatility and a narrowing of US-Japan interest rate spread indicates that the Yen carry trade is unwinding and that there is a statistically significant correlation between these metrics and volatility in US stocks.  More specifically, we believe that a principle component analysis (PCA) based index constructed from normalized JGB market indicators will exhibit statistically significant spikes preceding or concurrent with global volatility surges (VIX) during the August 2024 and January 2026 events.

# %% [markdown]
# ## Data

# %% [markdown]
# 1. The ideal dataset for this project would be a multi-source time-series dataset that captures indicators of yen carry trade stress in Japanese markets alongside measures of volatility in US equity markets. Since no single dataset directly measures carry trade activity, we will construct a composite dataset by merging multiple publicly available sources.
#     1. Key variables: USD/JPY (Dollar/Yen), Japenese Government Bond (JGB) yields and yeild volatility, US-Japan interest rate differentials, global market volatility metrics (VIX index), and date/time index for merging datasets
#
#     2. Ideally, the dataset will contain daily/weekly observations over the span of multiple years(e.g., 2010-2026).
#
#     3. Financial market data is collected automatically by exchanges, central banks, and economic data aggregators rather than surveys or expirements.
#
#     4. The data can be orginazed in a time-indexed tabular format, where each row represents a date and each column represents a financial variable. After getting data from different sources, the datasets would be merged using the timestamp and stored as cleaned pandas Dataframes for analysis.
#
#
# 2. These are the data sources we can use:
#
#     1. FRED (Federal Reserve Economic Data)
#         1. URL: "https://fred.stlouisfed.org/"
#
#         2. FRED provides downloadable CSV time-series datasets from central banks and financial institutions without the need of permission or application. The variables that are important include: Japanese yen exchange rate(USD/JPY), Japanese interest rate and government bond yields, VIX volatility index(global market risk indicator).
#
#     2. Ministry of Finance, Japan
#         1. URL: "https://www.mof.go.jp/english/policy/jgbs/reference/interest_rate/index.htm"
#
#         2. Historical Japanese Government Bond interest rate data is publicy available and downloadable as CSV files. The variables that are important include: JGB yield levels across maturities and yield chanages or volatility.
#
#     3. BOJ (Bank of Japan) Time-Series Data
#         1. URL: "https://www.stat-search.boj.or.jp/index_en.html"
#
#         2. This site is another that offers downloadable CSV files. BOJ also publishes official macroeconomic and financial statistics updated multiple times daily. Important variables include: policy interest rates, monetary policy indicators, and government bond market metrics.

# %% [markdown]
# ## Ethics
#
# Instructions: Keep the contents of this cell. For each item on the checklist
# -  put an X there if you've considered the item
# -  IF THE ITEM IS RELEVANT place a short paragraph after the checklist item discussing the issue.
#
# Items on this checklist are meant to provoke discussion among good-faith actors who take their ethical responsibilities seriously. Your teams will document these discussions and decisions for posterity using this section.  You don't have to solve these problems, you just have to acknowledge any potential harm no matter how unlikely.
#
# Here is a [list of real world examples](https://deon.drivendata.org/examples/) for each item in the checklist that can refer to.
#
# [![Deon badge](https://img.shields.io/badge/ethics%20checklist-deon-brightgreen.svg?style=popout-square)](http://deon.drivendata.org/)
#
# ### A. Data Collection
#  - [X] **A.1 Informed consent**: If there are human subjects, have they given informed consent, where subjects affirmatively opt-in and have a clear understanding of the data uses to which they consent?
#
#   Informed consent: Since our research utilizes public, aggregate financial market data—such as Japanese Government Bond yields and the VIX—there are no individual human subjects.
#
#  - [x] **A.2 Collection bias**: Have we considered sources of bias that could be introduced during data collection and survey design and taken steps to mitigate those?
# We have considered that financial data from free sources may contain lags or reporting differences compared to professional terminals. To mitigate this, we will use reputable sources like Yahoo Finance, and we will cross-reference dates to ensure accuracy during the volatile periods of August 2024 and January 2026.
#
#  - [x] **A.3 Limit PII exposure**: Have we considered ways to minimize exposure of personally identifiable information (PII) for example through anonymization or not collecting information that isn't relevant for analysis?
#
# Our dataset is comprised entirely of macroeconomic indicators and market indices. No personally identifiable information (PII) is collected or required for this analysis.
#
#
#  - [x] **A.4 Downstream bias mitigation**: Have we considered ways to enable testing downstream results for biased outcomes (e.g., collecting data on protected group status like race or gender)?
#
# While our data is primarily numerical market data, we recognize that financial models can reflect broader systemic biases. We will focus our analysis on the mechanical relationship between bond yields and volatility rather than making demographic-based inferences.
#
#
# ### B. Data Storage
#  - [x] **B.1 Data security**: Do we have a plan to protect and secure data (e.g., encryption at rest and in transit, access controls on internal users and third parties, access logs, and up-to-date software)?
#
#  All data and analysis will be stored in a private GitHub repository accessible only to team members and course staff. This ensures that our processed data remains secure throughout the project lifecycle.
#
#  - [x] **B.2 Right to be forgotten**: Do we have a mechanism through which an individual can request their personal information be removed?
#
#  As our data contains no personal information or individual records, a mechanism for individual data removal is not necessary for this specific project.
#
#  - [x] **B.3 Data retention plan**: Is there a schedule or plan to delete the data after it is no longer needed?
#
#  We plan to retain the data only for the duration of the COGS 108 course. Following the final submission and grading period, the repository will be archived or deleted according to course guidelines.
#
#
# ### C. Analysis
#  - [x] **C.1 Missing perspectives**: Have we sought to address blindspots in the analysis through engagement with relevant stakeholders (e.g., checking assumptions and discussing implications with affected communities and subject matter experts)?
#
#   Our analysis primarily focuses on quantitative market mechanics. However, we acknowledge that not all market factors are easily identified, so we will consider previous predictions to understand any factors that may not have been considered.
#
#  - [x] **C.2 Dataset bias**: Have we examined the data for possible sources of bias and taken steps to mitigate or address these biases (e.g., stereotype perpetuation, confirmation bias, imbalanced classes, or omitted confounding variables)?
#
#  We have examined the risk of "hindsight bias". To mitigate this, our model will be tested across both high-stress periods (August 2024, January 2026) and periods of relative stability to ensure the index does not produce frequent false positives.
#
#
#  - [x] **C.3 Honest representation**: Are our visualizations, summary statistics, and reports designed to honestly represent the underlying data?
#
#  Our visualizations will use standardized scales and statistic measurements to ensure that fluctuations in different variables,like JGB yields versus the VIX, are compared fairly and honestly.
#
#  - [x] **C.4 Privacy in analysis**: Have we ensured that data with PII are not used or displayed unless necessary for the analysis?
#
# Since we do not have data with PII, this will not be necessary.
#
#  - [x] **C.5 Auditability**: Is the process of generating the analysis well documented and reproducible if we discover issues in the future?
#
#  Our process, from data cleaning to Principal Component Analysis (PCA), will be fully documented in our Jupyter Notebook to ensure reproducibility by other researchers.
#
# ### D. Modeling
#  - [x] **D.1 Proxy discrimination**: Have we ensured that the model does not rely on variables or proxies for variables that are unfairly discriminatory?
#
# Since we are looking at quantatative data (bond yields and interest rate spreads), we do not believe that the variables will be unfairly discriminatory.
#
#  - [x] **D.2 Fairness across groups**: Have we tested model results for fairness with respect to different affected groups (e.g., tested for disparate error rates)?
#
# Our model focuses on macro-level indicators (JGB yields and global volatility); however, "unwind" events have disparate impacts on different market participants. High-frequency and institutional traders often have faster access to exit liquidity, while retail investors or smaller funds may bear a disproportionate burden of the subsequent market crash. To address this, we will compare our model's "stress alerts" against historical data for both large-cap and smaller-cap indices to evaluate if our index identifies risks equally well for different sectors.
#
#  - [x] **D.3 Metric selection**: Have we considered the effects of optimizing for our defined metrics and considered additional metrics?
#
# We have chosen the VIX as a primary validation metric, but we acknowledge that it primarily measures expected volatility in US equities. To avoid a singular metric, we will also consider the USD/JPY exchange rate velocity and JGB yield spreads as secondary metrics. This multi-metric approach ensures that our stress index isn't just a proxy for US market fear but captures the specific "funding currency" stress unique to the Yen carry trade.
#
#  - [x] **D.4 Explainability**: Can we explain in understandable terms a decision the model made in cases where a justification is needed?
#
#  By using PCA, we can explain which specific financial features (e.g., JGB yield change) contributed most heavily to the "stress index" at any given time, providing a clear rationale for the model's output.
#
#  - [x] **D.5 Communicate limitations**: Have we communicated the shortcomings, limitations, and biases of the model to relevant stakeholders in ways that can be generally understood?
#
#  We will clearly state that our model is a retrospective stress index and should be considered to be more of an educational prediction rather than a basis for financial trading or professional investment advice.
#
# ### E. Deployment
#  - [x] **E.1 Monitoring and evaluation**: Do we have a clear plan to monitor the model and its impacts after it is deployed (e.g., performance monitoring, regular audit of sample predictions, human review of high-stakes decisions, reviewing downstream impacts of errors or low-confidence decisions, testing for concept drift)?
#
# Since this is a retroactive view of the past and a prediction based on previous data, we do not have the need to be monitoring performance of the model. Addtionally, as this is not to be taken as professional advice, we do not anticipate a need for another professional's review and decision making ability.
#
#  - [x] **E.2 Redress**: Have we discussed with our organization a plan for response if users are harmed by the results (e.g., how does the data science team evaluate these cases and update analysis and models to prevent future harm)?
#
#  As we will explain in our findings that this is not to be taken as professional advice, we will be able to avoid any users that take personal initiative to act on the data and results that we produce in this assignment.
#
#  - [x] **E.3 Roll back**: Is there a way to turn off or roll back the model in production if necessary?
#
#  In the context of a Jupyter Notebook submission, "roll back" involves version control via Git. We are maintaining a clear history of our model iterations; if a specific analytical approach (like a certain PCA configuration) is found to be misleading or ethically questionable, we can revert to a previous, more stable version of the analysis.
#
#   - [x] **E.4 Unintended use**: Have we taken steps to identify and prevent unintended uses and abuse of the model and do we have a plan to monitor these once the model is deployed?
#
#   As this is a class assignment, the data and result will be restricted to the group and the teaching staff. Although we do not have the ability to control any classmates or viewers actions during the presentation, we will reference back to the disclaimer that we do not release our information for financial use.

# %% [markdown]
# ## Team Expectations

# %% [markdown]
# Instructions: REPLACE the contents of this cell with your work
#
# Read over the [COGS108 Team Policies](https://github.com/COGS108/Projects/blob/master/COGS108_TeamPolicies.md) individually. Then, include your group’s expectations of one another for successful completion of your COGS108 project below. Discuss and agree on what all of your expectations are. Discuss how your team will communicate throughout the quarter and consider how you will communicate respectfully should conflicts arise. By including each member’s name above and by adding their name to the submission, you are indicating that you have read the COGS108 Team Policies, accept your team’s expectations below, and have every intention to fulfill them. These expectations are for your team’s use and benefit — they won’t be graded for their details.
#
# * *Team Expectation 1*
# * *Team Expectation 2*
# * *Team Expecation 3*
# * ...

# %% [markdown]
# ## Project Timeline Proposal

# %% [markdown]
# Instructions: REPLACE the contents of this cell with your work
#
# Specify your team's specific project timeline. An example timeline has been provided. Changes the dates, times, names, and details to fit your group's plan.
#
# If you think you will need any special resources or training outside what we have covered in COGS 108 to solve your problem, then your proposal should state these clearly. For example, if you have selected a problem that involves implementing multiple neural networks, please state this so we can make sure you know what you’re doing and so we can point you to resources you will need to implement your project. Note that you are not required to use outside methods.
#
#
#
# | Meeting Date  | Meeting Time| Completed Before Meeting  | Discuss at Meeting |
# |---|---|---|---|
# | 1/20  |  1 PM | Read & Think about COGS 108 expectations; brainstorm topics/questions  | Determine best form of communication; Discuss and decide on final project topic; discuss hypothesis; begin background research |
# | 1/26  |  10 AM |  Do background research on topic | Discuss ideal dataset(s) and ethics; draft project proposal |
# | 2/1  | 10 AM  | Edit, finalize, and submit proposal; Search for datasets  | Discuss Wrangling and possible analytical approaches; Assign group members to lead each specific part   |
# | 2/14  | 6 PM  | Import & Wrangle Data (Ant Man); EDA (Hulk) | Review/Edit wrangling/EDA; Discuss Analysis Plan   |
# | 2/23  | 12 PM  | Finalize wrangling/EDA; Begin Analysis (Iron Man; Thor) | Discuss/edit Analysis; Complete project check-in |
# | 3/13  | 12 PM  | Complete analysis; Draft results/conclusion/discussion (Wasp)| Discuss/edit full project |
# | 3/20  | Before 11:59 PM  | NA | Turn in Final Project & Group Project Surveys |
